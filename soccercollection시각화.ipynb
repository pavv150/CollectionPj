# %%
dc = df[['홈','home','어웨이','away']]
print(df[['홈','어웨이']].iloc[2][0]+df[['홈','어웨이']].iloc[2][1])
dc['sample'] = dc[['홈','어웨이']].iloc[2][0]+df[['홈','어웨이']].iloc[2][1]
print(for i in range(len(dc['sample'])))
dc['sample'].loc[i] = dc[['홈','어웨이']].iloc[i+1][0]+df[['홈','어웨이']].iloc[i+1][1]
dc
# Out:
# 전북포항
# 37
# C:\Users\kgitbank401\AppData\Local\Temp\ipykernel_14620\4250816194.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dc['sample'] = dc[['홈','어웨이']].iloc[2][0]+df[['홈','어웨이']].iloc[2][1]
# C:\Users\kgitbank401\AppData\Local\Temp\ipykernel_14620\4250816194.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dc['sample'].loc[1] = dc[['홈','어웨이']].iloc[3][0]+df[['홈','어웨이']].iloc[3][1]
#      홈   home 어웨이   away sample
# 0   제주  62.58  포항  37.42   전북포항
# 1   김천  51.35  포항  48.65   인천포항
# 2   전북  61.29  포항  38.71   전북포항
# ...

# %% [markdown]
# # 삽질한 셈플

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('./test.csv',encoding='euc-kr')
# df =df[['점유율','홈','어웨이']]
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# dfstr = str(df.iloc[0:]).replace(' ','').split('\n')
# li = []
# for i in range(1,len(dfstr)):
#     if i > 10:
#         li.append(dfstr[i][2:])
#     else:
#         li.append(dfstr[i][1:])
# print(li)
    
# dfli = dfstr.split("\n")
df['home'] = df["점유율"].str[0:5]
df['away'] = df["점유율"].str[6:]

# print(df['홈'][0:])
li = []
li2 = []
for i in range(len(df[['홈','어웨이']].head(20))):
    li.append(df[['홈','어웨이']].iloc[i][0]+df[['홈','어웨이']].iloc[i][1])


dfha = df[['home','away']].head(20)
for i in range(len(dfha)):
    li2.append(float(dfha.loc[i][0]))
    li2.append(float(dfha.loc[i][1]))

# dfha.index.map(int)
# dfha.iloc[0:]= dfha.index.map(int)
print(li2[10:])
print(li)
dfha = pd.DataFrame({'홈':li2[0:20], '어웨이':li2[20:]},index=li)
dfha = dfha.plot.bar()
dfha


# dfha.plot.bar(x='team', y='score')
# print(dc['lab'][0])
# dfha = dfha.astype(float)

# dfha.plot.bar()
# Out:
# [51.37, 48.63, 32.79, 67.21, 52.79, 47.21, 40.4, 59.6, 55.2, 44.8, 56.42, 43.58, 67.64, 32.36, 58.78, 41.22, 46.46, 53.54, 43.74, 56.26, 44.46, 55.54, 54.1, 45.9, 53.08, 46.92, 33.13, 66.87, 42.37, 57.63]
# ['제주포항', '김천포항', '전북포항', '인천포항', '수원포항', '울산포항', '포항서울', '포항수원', '강원포항', '포항대구', '포항성남', '서울포항', '포항전북', '포항인천', '대구포항', '포항강원', '수원포항', '포항김천', '포항울산', '성남포항']
# <Axes: >

# %% [markdown]
# # 팀원들 csv 표로 만들기 (함수적용)

# %%
import pandas as pd
import seaborn as sns
from matplotlib import font_manager, rc

df = pd.read_csv('./test.csv',encoding='euc-kr')
df2 = pd.read_csv('./test2.csv',encoding='euc-kr')
df3 = pd.read_csv('./ulsan.csv',encoding='euc-kr')
df4 = pd.read_csv('./HSY.csv',encoding='utf-8')

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

def csv(df):
    df['home'] = df["점유율"].str[0:5]
    df['away'] = df["점유율"].str[6:]

    li = []
    li2 = []
    for i in range(len(df[['홈','어웨이']].head(10))):
        li.append(df[['홈','어웨이']].iloc[i][0]+'  '+df[['홈','어웨이']].iloc[i][1])

    dfha = df[['home','away']].head(10)
    for i in range(len(dfha)):
        li2.append(float(dfha.loc[i][0]))
        li2.append(float(dfha.loc[i][1]))

    dfha = pd.DataFrame({'홈':li2[0:10], '어웨이':li2[10:]},index=li)
    dfha = dfha.plot.bar()
    dfha
csv(df)
print('왼쪽:파랑  오른쪽:주황 (90도 회전 기준!)')
csv(df2)
csv(df3)
# Out:
# 왼쪽:파랑  오른쪽:주황 (90도 회전 기준!)
